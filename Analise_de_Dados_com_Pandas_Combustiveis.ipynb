# %% [markdown]
# <a href="https://colab.research.google.com/github/FelipeArgona/AnaliseDeDadosPandasArgona/blob/main/Analise_de_Dados_com_Pandas_Combustiveis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula de verão Analise de dados com Pandas

# %%
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#import da biblioteca e carregamento do data frame

import pandas as pd

comb_df = pd.read_excel("/content/drive/MyDrive/ca-NOV-2021-02.xlsx")

# %%
#ver o data frame

print(comb_df)
# Out:
#        Regiao - Sigla Estado - Sigla  Municipio  \
# 0                  NE             AL  ARAPIRACA
# 1                  NE             AL  ARAPIRACA
# 2                  NE             AL  ARAPIRACA
# 3                  NE             AL  ARAPIRACA
# 4                  NE             AL  ARAPIRACA
# ...               ...            ...        ...
# 168404             NE             BA     JEQUIE
# 168405             SE             MG  ITUIUTABA
# 168406             SE             MG  ITUIUTABA
# 168407             SE             MG  ITUIUTABA
# 168408             SE             MG  ITUIUTABA
#
#                                            Revenda      CNPJ da Revenda  \
# 0                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 1                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 2                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 3                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# ...

# %%
display(comb_df)
# Out:
#        Regiao - Sigla Estado - Sigla  Municipio  \
# 0                  NE             AL  ARAPIRACA
# 1                  NE             AL  ARAPIRACA
# 2                  NE             AL  ARAPIRACA
# 3                  NE             AL  ARAPIRACA
# 4                  NE             AL  ARAPIRACA
# ...               ...            ...        ...
# 168404             NE             BA     JEQUIE
# 168405             SE             MG  ITUIUTABA
# 168406             SE             MG  ITUIUTABA
# 168407             SE             MG  ITUIUTABA
# 168408             SE             MG  ITUIUTABA
#
#                                            Revenda      CNPJ da Revenda  \
# 0                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 1                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 2                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 3                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# ...

# %%
#shape e describe

print(comb_df.shape)

print(comb_df.describe())
# Out:
# (168409, 16)
#        Valor de Venda  Valor de Compra
# count   168409.000000              0.0
# mean         6.005184              NaN
# std          0.794541              NaN
# min          2.849000              NaN
# 25%          5.339000              NaN
# 50%          5.859000              NaN
# 75%          6.699000              NaN
# max          8.990000              NaN

# %%
#head

display(comb_df.head(5))
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio               Revenda  \
# 0             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 1             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 2             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 3             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 4             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
#
#        CNPJ da Revenda     Nome da Rua Numero Rua Complemento       Bairro  \
# 0   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 1   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 2   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 3   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 4   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
#
#          Cep             Produto Data da Coleta  Valor de Venda  \
# ...

# %%
print(comb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168409 entries, 0 to 168408
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     168409 non-null  object
#  1   Estado - Sigla     168409 non-null  object
#  2   Municipio          168409 non-null  object
#  3   Revenda            168409 non-null  object
#  4   CNPJ da Revenda    168409 non-null  object
#  5   Nome da Rua        168409 non-null  object
#  6   Numero Rua         168353 non-null  object
#  7   Complemento        35057 non-null   object
#  8   Bairro             168043 non-null  object
#  9   Cep                168409 non-null  object
#  10  Produto            168409 non-null  object
#  11  Data da Coleta     168409 non-null  datetime64[ns]
#  12  Valor de Venda     168409 non-null  float64
#  13  Valor de Compra    0 non-null       float64
#  14  Unidade de Medida  168409 non-null  object
# ...

# %%
#Aqui criamos um novo dataframe apenas com as colunas desejadas 
ca_df = comb_df[['Revenda','Municipio','Produto','Valor de Venda']]
display(ca_df)
# Out:
#                                            Revenda  Municipio  \
# 0                             POSTO ARAPIRACA LTDA  ARAPIRACA
# 1                             POSTO ARAPIRACA LTDA  ARAPIRACA
# 2                             POSTO ARAPIRACA LTDA  ARAPIRACA
# 3                             POSTO ARAPIRACA LTDA  ARAPIRACA
# 4                             POSTO ARAPIRACA LTDA  ARAPIRACA
# ...                                            ...        ...
# 168404  COMERCIAL DE COMBUSTIVEL CACHOEIRINHA LTDA     JEQUIE
# 168405           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA
# 168406           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA
# 168407           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA
# 168408           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA
#
#                    Produto  Valor de Venda
# 0                 GASOLINA           6.799
# 1                   ETANOL           5.299
# 2                   DIESEL           5.549
# 3       GASOLINA ADITIVADA           6.899
# ...

# %%
#Locaizando preços de etanol em INDAITUBA
# Sort

etanol_inda_df = ca_df.loc[(ca_df['Produto'] == 'ETANOL') & (ca_df ['Municipio']== 'INDAIATUBA')]
etanol_inda_df.sort_values(by='Valor de Venda', inplace = True)
display(etanol_inda_df)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#                                         Revenda   Municipio Produto  \
# 160592             AUTO POSTO NAMORADA II LTDA.  INDAIATUBA  ETANOL
# 140194  CENTRO AUTOMOTIVO RIVIERA TROPICAL LTDA  INDAIATUBA  ETANOL
# 140661      M.LI COMERCIO DE COMBUSTIVEIS LTDA.  INDAIATUBA  ETANOL
# 159497      M.LI COMERCIO DE COMBUSTIVEIS LTDA.  INDAIATUBA  ETANOL
# 141167      AUTO POSTO ESPLANADA DE INDAIA LTDA  INDAIATUBA  ETANOL
# ...                                         ...         ...     ...
# 51129          AUTO POSTO CIDADE DO SOL II LTDA  INDAIATUBA  ETANOL
# 51138              AUTO POSTO NAMORADA II LTDA.  INDAIATUBA  ETANOL
# ...

# %%
#Qual a media de preços dos combustiveis gasolina e gasolina aditivada do bairro Bela vista em são paulo
#funcao isin

#comb_sp = comb_df.loc[(comb_df['Bairro'] == 'MOOCA') & (comb_df['Municipio'] == 'SAO PAULO') & ((comb_df['Produto'] == 'GASOLINA') | (comb_df['Produto'] == 'GASOLINA ADITIVADA'))]

comb_sp = comb_df.loc[(comb_df['Bairro'] == 'MOOCA') & 
                      (comb_df['Municipio'] == 'SAO PAULO') & 
                      (comb_df['Produto'].isin(['GASOLINA', 'GASOLINA ADITIVADA']))]

comb_sp = comb_sp [['Revenda','Municipio','Bairro','Produto','Valor de Venda']]
comb_sp.sort_values(by='Valor de Venda', inplace = True)
display(comb_sp.mean())
display(comb_sp)
# Out:
# <ipython-input-50-63819fd9246f>:12: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   display(comb_sp.mean())
# Valor de Venda    6.575596
# dtype: float64
#                                                   Revenda  Municipio Bairro  \
# 11590                                 AUTO POSTO LIK LTDA  SAO PAULO  MOOCA
# 139297                            AUTO POSTO PANTERA LTDA  SAO PAULO  MOOCA
# 11648                             AUTO POSTO PANTERA LTDA  SAO PAULO  MOOCA
# 103242                NOVO BRILHO CENTRO AUTOMOTIVO  LTDA  SAO PAULO  MOOCA
# 66374                 NOVO BRILHO CENTRO AUTOMOTIVO  LTDA  SAO PAULO  MOOCA
# 142001                NOVO BRILHO CENTRO AUTOMOTIVO  LTDA  SAO PAULO  MOOCA
# 11646                             AUTO POSTO PANTERA LTDA  SAO PAULO  MOOCA
# ...

# %%
from numpy import shape
shape(comb_sp)
# Out:
# (47, 5)

# %%
# Media de valor geral por tipo de combustivel
# Round para casas decimais

media_comb_df = ca_df[['Produto', 'Valor de Venda']].groupby(by='Produto').mean().round(2)
display(media_comb_df)
# Out:
#                     Valor de Venda
# Produto
# DIESEL                        5.38
# DIESEL S10                    5.45
# ETANOL                        5.46
# GASOLINA                      6.71
# GASOLINA ADITIVADA            6.86
# GNV                           4.39

# %%
# Para adicionar uma coluna de valor booleano em nosso data frame
# Por default será true para todas as linhas

comb_df['Ativo'] = True
comb_df.shape
display(comb_df)
# Out:
#        Regiao - Sigla Estado - Sigla  Municipio  \
# 0                  NE             AL  ARAPIRACA
# 1                  NE             AL  ARAPIRACA
# 2                  NE             AL  ARAPIRACA
# 3                  NE             AL  ARAPIRACA
# 4                  NE             AL  ARAPIRACA
# ...               ...            ...        ...
# 168404             NE             BA     JEQUIE
# 168405             SE             MG  ITUIUTABA
# 168406             SE             MG  ITUIUTABA
# 168407             SE             MG  ITUIUTABA
# 168408             SE             MG  ITUIUTABA
#
#                                            Revenda      CNPJ da Revenda  \
# 0                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 1                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 2                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 3                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# ...

# %%
# Condicionando a coluna uma coluna 'OBS'
# que preencha "MINHA CIDADE" quando o Municipio for sao paulo

#comb_df['Obs'] = "MINHA CIDADE" is comb_df['MINICIPIO'] == 'SAO PAULO' else ""

# %%
#Exportar saída

comb_sp.to_excel('combustivel_sp.xlsx', sheet_name='Combustiveis em sao paulo')
